# %% [markdown]
# # Stable Baselines
#
# Stable Baselines is a set of high-quality implementations of reinforcement learning algorithms in Python. It is built on top of OpenAI Gym (Gymnasium) and provides a user-friendly interface for training, evaluating, and deploying RL agents. Stable Baselines offers a wide range of popular RL algorithms, including Proximal Policy Optimization (PPO), Deep Q-Networks (DQN), and Trust Region Policy Optimization (TRPO), among others. It aims to provide reliable and stable implementations that are extensively tested and documented, making it easier for researchers and practitioners to work with reinforcement learning.

# %%
# Check the version of the installed versions
import gym as gym
import stable_baselines3 as sb3
import torch
import numpy as np

print(f"Gymnasium version: {gym.__version__}")
print(f"Stable Baselines version : {sb3.__version__}")
print(f"Torch version : {torch.__version__}")
print(f"Numpy version : {np.__version__}")
# Out:
# Gymnasium version: 0.25.2
# Stable Baselines version : 2.2.1
# Torch version : 2.1.0+cu121
# Numpy version : 1.23.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files

# Video management imports
import cv2

# Helper functions to save videos and images
def save_video(img_array, path='/content/video/test.mp4'):
    height, width, layers = img_array[0].shape
    size = (width, height)
    out = cv2.VideoWriter(path, cv2.VideoWriter_fourcc(*'mp4v'), 15, size)
    for i in range(len(img_array)):
        bgr_img = cv2.cvtColor(img_array[i], cv2.COLOR_RGB2BGR)
        out.write(bgr_img)
    out.release()
    print('Video saved.')



def save_images(img_array, path='./images'):
    for i, image in enumerate(img_array):
        bgr_img = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(path + '/img_' + str(i) + '.jpg', bgr_img)

# %%
# Video management imports
import cv2

# Helper functions to save videos and images


def save_video(img_array, path='./video/test.mp4'):
    height, width, layers = img_array[0].shape
    size = (width, height)
    out = cv2.VideoWriter(path, cv2.VideoWriter_fourcc(*'mp4v'), 15, size)
    for i in range(len(img_array)):
        bgr_img = cv2.cvtColor(img_array[i], cv2.COLOR_RGB2BGR)
        out.write(bgr_img)
    out.release()
    print('Video saved.')


def save_images(img_array, path='./images'):
    for i, image in enumerate(img_array):
        bgr_img = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(path + '/img_' + str(i) + '.jpg', bgr_img)

# %% [markdown]
# ## Basic Training
#
# To train an agent we only need an algorithm object an environment and a call to the learn function.

# %%
from stable_baselines3 import A2C

env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1, learning_rate=0.001)
model.learn(total_timesteps=10_000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.6     |
# |    ep_rew_mean        | 15.6     |
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 100      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | 0.22     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 99       |
# |    policy_loss        | 2.15     |
# |    value_loss         | 9.45     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.3     |
# |    ep_rew_mean        | 19.3     |
# | time/                 |          |
# |    fps                | 230      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.673   |
# |    explained_variance | 0.235    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 199      |
# |    policy_loss        | 1.32     |
# |    value_loss         | 4.26     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22       |
# |    ep_rew_mean        | 22       |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0.0289   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 299      |
# |    policy_loss        | 1.13     |
# |    value_loss         | 6.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.1     |
# |    ep_rew_mean        | 27.1     |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | -0.0153  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 399      |
# |    policy_loss        | 1.47     |
# |    value_loss         | 5.33     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.3     |
# |    ep_rew_mean        | 30.3     |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | 0.00277  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 499      |
# |    policy_loss        | 1.06     |
# |    value_loss         | 4.4      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.9     |
# |    ep_rew_mean        | 35.9     |
# | time/                 |          |
# |    fps                | 338      |
# |    iterations         | 600      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.581   |
# |    explained_variance | -0.00394 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 599      |
# |    policy_loss        | 0.649    |
# |    value_loss         | 3.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.7     |
# |    ep_rew_mean        | 37.7     |
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 700      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.577   |
# |    explained_variance | 0.00316  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 699      |
# |    policy_loss        | 0.748    |
# |    value_loss         | 3        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.1     |
# |    ep_rew_mean        | 40.1     |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 800      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | -0.00059 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 799      |
# |    policy_loss        | 0.644    |
# |    value_loss         | 2.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.1     |
# |    ep_rew_mean        | 43.1     |
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 900      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.602   |
# |    explained_variance | 7.39e-06 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 899      |
# |    policy_loss        | 0.784    |
# |    value_loss         | 1.81     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.6      |
# |    ep_rew_mean        | 48.6      |
# | time/                 |           |
# |    fps                | 369       |
# |    iterations         | 1000      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.544    |
# |    explained_variance | -0.000263 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | 0.487     |
# |    value_loss         | 1.32      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 53.4      |
# |    ep_rew_mean        | 53.4      |
# | time/                 |           |
# |    fps                | 371       |
# |    iterations         | 1100      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.308    |
# |    explained_variance | -3.91e-05 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1099      |
# |    policy_loss        | -46.7     |
# |    value_loss         | 4.59e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 56.6     |
# |    ep_rew_mean        | 56.6     |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 1200     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | 1.32e-05 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.304    |
# |    value_loss         | 0.591    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 61.3      |
# |    ep_rew_mean        | 61.3      |
# | time/                 |           |
# |    fps                | 382       |
# |    iterations         | 1300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.517    |
# |    explained_variance | -0.000422 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.145     |
# |    value_loss         | 0.338     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 65       |
# |    ep_rew_mean        | 65       |
# | time/                 |          |
# |    fps                | 387      |
# |    iterations         | 1400     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | 2.63e-05 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.169    |
# |    value_loss         | 0.148    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 69.8      |
# |    ep_rew_mean        | 69.8      |
# | time/                 |           |
# |    fps                | 391       |
# |    iterations         | 1500      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.536    |
# |    explained_variance | -0.000295 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.055     |
# |    value_loss         | 0.0298    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.7     |
# |    ep_rew_mean        | 74.7     |
# | time/                 |          |
# |    fps                | 395      |
# |    iterations         | 1600     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.57    |
# |    explained_variance | -0.00409 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.00555  |
# |    value_loss         | 0.000353 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 78.6     |
# |    ep_rew_mean        | 78.6     |
# | time/                 |          |
# |    fps                | 399      |
# |    iterations         | 1700     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.432   |
# |    explained_variance | -0.0432  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.00139  |
# |    value_loss         | 1.24e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.4     |
# |    ep_rew_mean        | 81.4     |
# | time/                 |          |
# |    fps                | 402      |
# |    iterations         | 1800     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.555   |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1799     |
# |    policy_loss        | -8.4e-05 |
# |    value_loss         | 1.86e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 86.9      |
# |    ep_rew_mean        | 86.9      |
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 1900      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.577    |
# |    explained_variance | -1.73e-05 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1899      |
# |    policy_loss        | -22       |
# |    value_loss         | 3.88e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.1     |
# |    ep_rew_mean        | 90.1     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 2000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.546   |
# |    explained_variance | 0.00121  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00455  |
# |    value_loss         | 6.23e-05 |
# ------------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.

# %% [markdown]
# ## Custom network

# %%
from stable_baselines3 import PPO

# Custom actor (pi) and value function (vf) networks
# of two layers of size 32 each with Relu activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
policy_kwargs = dict(activation_fn=torch.nn.ReLU,
                     net_arch=dict(pi=[64, 64], vf=[64, 64]))
# Create the agent
model = PPO("MlpPolicy", "CartPole-v1", policy_kwargs=policy_kwargs, verbose=1)
# Retrieve the environment
env = model.get_env()
# Train the agent
model.learn(total_timesteps=30_000)

# %% [markdown]
# Stable Baselines also enables to save and reload the model from a file

# %%
# Save the agent
# model.save("ppo_cartpole")
# del model
# the policy_kwargs are automatically loaded
# model = PPO.load("ppo_cartpole", env=env)

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.

# %% [markdown]
# Let's try another environmet Acrobot

# %%
# Custom actor (pi) and value function (vf) networks
# of two layers of size 32 each with Relu activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
policy_kwargs = dict(activation_fn=torch.nn.ReLU,
                     net_arch=dict(pi=[64, 64], vf=[64, 64]))
# Create the agent
model = PPO("MlpPolicy", "Acrobot-v1", policy_kwargs=policy_kwargs, verbose=1)
# Retrieve the environment
env = model.get_env()
# Train the agent
model.learn(total_timesteps=30_000)

# %% [markdown]
# Let's see the results:

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _, _ = model.select_action(observation)
    observation, reward, done, truncated, info = env.step(action)
    done = done or truncated
    image = env.render()
    img_array.append(image)
env.close()

save_video(imgs, path='video/sb3_ppo_acrobot.mp4')

# %% [markdown]
# ## Using a custom network with Pytorch
#
# We can train our agent with a custom network. In this case we will create a simple module for an actor-critic network. We need an adapter class *CustomActorCriticPolicy* to adapt our network to the needs of the algorithm and the environment.

# %%
from typing import Callable, Dict, List, Optional, Tuple, Type, Union

from stable_baselines3.common.policies import ActorCriticPolicy
from gymnasium import spaces
import torch
from torch import nn

class CustomNetwork(nn.Module):
    """
    Custom network for policy and value function.
    It receives as input the features extracted by the features extractor.

    :param feature_dim: dimension of the features extracted with the features_extractor (e.g. features from a CNN)
    :param last_layer_dim_pi: (int) number of units for the last layer of the policy network
    :param last_layer_dim_vf: (int) number of units for the last layer of the value network
    """

    def __init__(
        self,
        obs_space_size: int,
        last_layer_dim_pi: int = 64,
        last_layer_dim_vf: int = 64,
    ):
        super().__init__()

        # IMPORTANT:
        # Save output dimensions, used to create the distributions
        self.latent_dim_pi = last_layer_dim_pi
        self.latent_dim_vf = last_layer_dim_vf

        # Policy network
        self.policy_net = nn.Sequential(
            nn.Linear(obs_space_size, last_layer_dim_pi), nn.ReLU()
        )
        # Value network
        self.value_net = nn.Sequential(
            nn.Linear(obs_space_size, last_layer_dim_vf), nn.ReLU()
        )

    def forward(self, features: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        :return: (th.Tensor, th.Tensor) latent_policy, latent_value of the specified network.
            If all layers are shared, then ``latent_policy == latent_value``
        """
        return self.forward_actor(features), self.forward_critic(features)

    def forward_actor(self, features: torch.Tensor) -> torch.Tensor:
        return self.policy_net(features)

    def forward_critic(self, features: torch.Tensor) -> torch.Tensor:
        return self.value_net(features)

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.

# %%
# This class will be automatically called by our algorithm with the adecuate
# dimensions
class CustomActorCriticPolicy(ActorCriticPolicy):
    def __init__(
        self,
        observation_space: spaces.Space,
        action_space: spaces.Space,
        lr_schedule: Callable[[float], float],
        *args,
        **kwargs,
    ):
        # Disable orthogonal initialization
        kwargs["ortho_init"] = False
        super().__init__(
            observation_space,
            action_space,
            lr_schedule,
            # Pass remaining arguments to base class
            *args,
            **kwargs,
        )


    def _build_mlp_extractor(self) -> None:
        self.mlp_extractor = CustomNetwork(self.features_dim)


model = PPO(CustomActorCriticPolicy, "CartPole-v1", verbose=0)
# Another way to show the progress of the training
model.learn(30_000, progress_bar=True)

# %% [markdown]
# # Exercises
#
# 1. Select an environment with a continuous action space from Gymnasium (not atari) and try to train it.

# %%
# This class will be automatically called by our algorithm with the adecuate
# dimensions
class CustomActorCriticPolicy(ActorCriticPolicy):
    def __init__(
        self,
        observation_space: spaces.Space,
        action_space: spaces.Space,
        lr_schedule: Callable[[float], float],
        *args,
        **kwargs,
    ):
        # Disable orthogonal initialization
        kwargs["ortho_init"] = False
        super().__init__(
            observation_space,
            action_space,
            lr_schedule,
            # Pass remaining arguments to base class
            *args,
            **kwargs,
        )


    def _build_mlp_extractor(self) -> None:
        self.mlp_extractor = CustomNetwork(self.features_dim)


model = PPO(CustomActorCriticPolicy, "MountainCarContinuous-v0", verbose=0)
# Another way to show the progress of the training
model.learn(30_000, progress_bar=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from stable_baselines3 import PPO
import torch

# Custom actor (pi) and value function (vf) networks
# of two layers of size 64 each with ReLU activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
policy_kwargs = dict(
    net_arch=dict(pi=[64, 64], vf=[64, 64]), activation_fn=torch.nn.ReLU
)

ent_coef = 0.7
learning_rate = 0.0003  # Experiment with different values

# Create the agent
model = PPO("MlpPolicy", "MountainCarContinuous-v0", policy_kwargs=policy_kwargs, verbose=1,ent_coef = ent_coef, learning_rate=learning_rate)

# Retrieve the environment
env = model.get_env()

# Train the agent
model.learn(total_timesteps=200000)
# Out:
# Using cuda device
# Creating environment from the given name 'MountainCarContinuous-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -53.5    |
# | time/              |          |
# |    fps             | 832      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -54.4        |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0116092395 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.00562     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.03        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.0153       |
# |    std                  | 1.11         |
# |    value_loss           | 0.177        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -55.8       |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009508675 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.0424      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 1.23        |
# |    value_loss           | 0.0485      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -57.5       |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008504925 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | -0.115      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.19       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.0118      |
# |    std                  | 1.35        |
# |    value_loss           | 0.0377      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 939         |
# |    ep_rew_mean          | -45         |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 5           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008190919 |
# |    clip_fraction        | 0.0291      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.000204    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.24       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0107      |
# |    std                  | 1.49        |
# |    value_loss           | 0.0295      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 949          |
# |    ep_rew_mean          | -48.5        |
# | time/                   |              |
# |    fps                  | 545          |
# |    iterations           | 6            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0013092502 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.00382      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.48         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 0.000782     |
# |    std                  | 1.55         |
# |    value_loss           | 41.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 956         |
# |    ep_rew_mean          | -51.3       |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 7           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012256255 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -0.147      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.28       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00142     |
# |    std                  | 1.73        |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 957          |
# |    ep_rew_mean          | -48.7        |
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 8            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0135678975 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | -0.275       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.44        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.00777      |
# |    std                  | 1.92         |
# |    value_loss           | 0.0271       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 961          |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 522          |
# |    iterations           | 9            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0014235725 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.0738       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.7         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000847    |
# |    std                  | 1.98         |
# |    value_loss           | 42.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 10          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010095492 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.42       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00097     |
# |    std                  | 2.18        |
# |    value_loss           | 0.232       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 956         |
# |    ep_rew_mean          | -50.7       |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 11          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011802796 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | -0.315      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.58       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00605     |
# |    std                  | 2.43        |
# |    value_loss           | 0.0498      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | -48.3        |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 12           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0006936176 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.0717       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.41        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.000557     |
# |    std                  | 2.5          |
# |    value_loss           | 40.5         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 956           |
# |    ep_rew_mean          | -50.6         |
# | time/                   |               |
# |    fps                  | 512           |
# |    iterations           | 13            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00048282114 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.35         |
# |    explained_variance   | 0.25          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.226         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -5.51e-05     |
# |    std                  | 2.56          |
# |    value_loss           | 35.1          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 959         |
# |    ep_rew_mean          | -52.6       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 14          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005770235 |
# |    clip_fraction        | 0.0179      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | -0.39       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.58       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00229     |
# |    std                  | 2.77        |
# |    value_loss           | 0.458       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 962         |
# |    ep_rew_mean          | -54.7       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 15          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012316649 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | -0.132      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.77       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00527     |
# |    std                  | 3.12        |
# |    value_loss           | 0.0632      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 961         |
# |    ep_rew_mean          | -54.1       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 16          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011247557 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | -0.535      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.84       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00693     |
# |    std                  | 3.49        |
# |    value_loss           | 0.0259      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 963           |
# |    ep_rew_mean          | -55.8         |
# | time/                   |               |
# |    fps                  | 510           |
# |    iterations           | 17            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00050290965 |
# |    clip_fraction        | 0.000684      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.68         |
# |    explained_variance   | 0.256         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 51            |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000421     |
# |    std                  | 3.56          |
# |    value_loss           | 36.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | -53.8        |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 18           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0027066236 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.0321       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.73        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.000973     |
# |    std                  | 3.77         |
# |    value_loss           | 0.911        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 957          |
# |    ep_rew_mean          | -55.5        |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 19           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0004898483 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.8         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000203     |
# |    std                  | 3.84         |
# |    value_loss           | 40.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 959          |
# |    ep_rew_mean          | -56.9        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 20           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0044487603 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.79        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 7.73e-05     |
# |    std                  | 4.12         |
# |    value_loss           | 0.805        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 956         |
# |    ep_rew_mean          | -54.1       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 21          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015774528 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.00579     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -2.05       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00403     |
# |    std                  | 4.71        |
# |    value_loss           | 0.0414      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 957          |
# |    ep_rew_mean          | -53.4        |
# | time/                   |              |
# |    fps                  | 505          |
# |    iterations           | 22           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0005247394 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7            |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000497    |
# |    std                  | 4.77         |
# |    value_loss           | 79.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 959           |
# |    ep_rew_mean          | -54.9         |
# | time/                   |               |
# |    fps                  | 506           |
# |    iterations           | 23            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00029573604 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.99         |
# |    explained_variance   | 0.373         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.75          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 4.04e-05      |
# |    std                  | 4.85          |
# |    value_loss           | 32.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 942         |
# |    ep_rew_mean          | -49.4       |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 24          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.001253688 |
# |    clip_fraction        | 0.00347     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.12       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00024     |
# |    std                  | 5.02        |
# |    value_loss           | 3.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 945          |
# |    ep_rew_mean          | -50.9        |
# | time/                   |              |
# |    fps                  | 504          |
# |    iterations           | 25           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 6.985283e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.7         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -7.08e-05    |
# |    std                  | 5.07         |
# |    value_loss           | 92.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 946          |
# |    ep_rew_mean          | -52.3        |
# | time/                   |              |
# |    fps                  | 505          |
# |    iterations           | 26           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0034410679 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | -0.467       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.84        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000524     |
# |    std                  | 5.41         |
# |    value_loss           | 0.799        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 948         |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 27          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.014626735 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | -0.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -2.24       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0036      |
# |    std                  | 6.15        |
# |    value_loss           | 0.0882      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 942         |
# |    ep_rew_mean          | -50.9       |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 28          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016515952 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -2.34       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00473     |
# |    std                  | 6.98        |
# |    value_loss           | 0.032       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 928           |
# |    ep_rew_mean          | -48.1         |
# | time/                   |               |
# |    fps                  | 504           |
# |    iterations           | 29            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00015653009 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.37         |
# |    explained_variance   | 0.343         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 62.9          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000271     |
# |    std                  | 7.04          |
# |    value_loss           | 75            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 914           |
# |    ep_rew_mean          | -46.1         |
# | time/                   |               |
# |    fps                  | 504           |
# |    iterations           | 30            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00010473121 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.37         |
# |    explained_variance   | 0.429         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 20.8          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000351     |
# |    std                  | 7.1           |
# |    value_loss           | 57.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 917           |
# |    ep_rew_mean          | -47.5         |
# | time/                   |               |
# |    fps                  | 502           |
# |    iterations           | 31            |
# |    time_elapsed         | 126           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00022248563 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.38         |
# |    explained_variance   | 0.535         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 45.9          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.001        |
# |    std                  | 7.15          |
# |    value_loss           | 64.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 919          |
# |    ep_rew_mean          | -47.3        |
# | time/                   |              |
# |    fps                  | 503          |
# |    iterations           | 32           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0032205628 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.4         |
# |    explained_variance   | -0.472       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -2.01        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000495    |
# |    std                  | 7.45         |
# |    value_loss           | 1.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -45.1        |
# | time/                   |              |
# |    fps                  | 503          |
# |    iterations           | 33           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0008688575 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.43        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.36        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000698    |
# |    std                  | 7.56         |
# |    value_loss           | 23.5         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 897           |
# |    ep_rew_mean          | -43.1         |
# | time/                   |               |
# |    fps                  | 501           |
# |    iterations           | 34            |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00060167373 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.45         |
# |    explained_variance   | 0.64          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 27.7          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000605     |
# |    std                  | 7.65          |
# |    value_loss           | 42.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 892           |
# |    ep_rew_mean          | -40.4         |
# | time/                   |               |
# |    fps                  | 502           |
# |    iterations           | 35            |
# |    time_elapsed         | 142           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00097072404 |
# |    clip_fraction        | 0.000684      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.46         |
# |    explained_variance   | 0.692         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.44          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00123      |
# |    std                  | 7.73          |
# |    value_loss           | 48.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 892          |
# |    ep_rew_mean          | -40.3        |
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 36           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0003105121 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.47        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.76         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000254    |
# |    std                  | 7.79         |
# |    value_loss           | 69.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 889           |
# |    ep_rew_mean          | -38           |
# | time/                   |               |
# |    fps                  | 501           |
# |    iterations           | 37            |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00060077105 |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.48         |
# |    explained_variance   | 0.715         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 45.3          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000607     |
# |    std                  | 7.88          |
# |    value_loss           | 34.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 887           |
# |    ep_rew_mean          | -37.7         |
# | time/                   |               |
# |    fps                  | 501           |
# |    iterations           | 38            |
# |    time_elapsed         | 155           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00028354774 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.49         |
# |    explained_variance   | 0.774         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 13.7          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 2e-05         |
# |    std                  | 7.98          |
# |    value_loss           | 42.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 890           |
# |    ep_rew_mean          | -39           |
# | time/                   |               |
# |    fps                  | 501           |
# |    iterations           | 39            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00045902506 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.5          |
# |    explained_variance   | 0.78          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.7           |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -1.18e-05     |
# |    std                  | 8.12          |
# |    value_loss           | 22.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | -39.1        |
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 40           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0015730287 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.53        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.37        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000129    |
# |    std                  | 8.35         |
# |    value_loss           | 8.06         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 883          |
# |    ep_rew_mean          | -38          |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 41           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0025881806 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.55        |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28           |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00154     |
# |    std                  | 8.54         |
# |    value_loss           | 24.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 877          |
# |    ep_rew_mean          | -35.8        |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 42           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0013706364 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.57        |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000381    |
# |    std                  | 8.69         |
# |    value_loss           | 45.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 860          |
# |    ep_rew_mean          | -32.9        |
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 43           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0004719672 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.59        |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000482    |
# |    std                  | 8.83         |
# |    value_loss           | 64.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 845          |
# |    ep_rew_mean          | -29.7        |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 44           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0015800288 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.61        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.41         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 9.06         |
# |    value_loss           | 30.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 836          |
# |    ep_rew_mean          | -27.9        |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 45           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0028963014 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.63        |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.72         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00083     |
# |    std                  | 9.26         |
# |    value_loss           | 39.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 827           |
# |    ep_rew_mean          | -24.9         |
# | time/                   |               |
# |    fps                  | 499           |
# |    iterations           | 46            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00063054985 |
# |    clip_fraction        | 0.000635      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.66         |
# |    explained_variance   | 0.851         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 13.2          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 8.31e-06      |
# |    std                  | 9.47          |
# |    value_loss           | 47.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 809          |
# |    ep_rew_mean          | -20.2        |
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 47           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0033994624 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.68        |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.8         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00172     |
# |    std                  | 9.69         |
# |    value_loss           | 46.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 790         |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 48          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.003943703 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00037    |
# |    std                  | 9.95        |
# |    value_loss           | 43.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 789          |
# |    ep_rew_mean          | -16.6        |
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 49           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0020477762 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.73        |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00067     |
# |    std                  | 10.3         |
# |    value_loss           | 35.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 792          |
# |    ep_rew_mean          | -18.1        |
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 50           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0016243882 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.77        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000161     |
# |    std                  | 10.6         |
# |    value_loss           | 33.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 774         |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 51          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008165346 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00303    |
# |    std                  | 11          |
# |    value_loss           | 34.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 762        |
# |    ep_rew_mean          | -11.3      |
# | time/                   |            |
# |    fps                  | 500        |
# ...
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 675          |
# |    ep_rew_mean          | 15.8         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 82           |
# |    time_elapsed         | 334          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0025168357 |
# |    clip_fraction        | 0.00918      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.06        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.882        |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.000497    |
# |    std                  | 106          |
# |    value_loss           | 23.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 673         |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 83          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.014297855 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.15       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -2.66       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.000894    |
# |    std                  | 121         |
# |    value_loss           | 4.54        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 680          |
# |    ep_rew_mean          | 14.1         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 84           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0036727304 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.65         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.000418    |
# |    std                  | 129          |
# |    value_loss           | 10.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 693         |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 85          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.002965026 |
# |    clip_fraction        | 0.00957     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.3        |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.998      |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.000943    |
# |    std                  | 136         |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 695         |
# |    ep_rew_mean          | 11.6        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 86          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.017252468 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.41       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -3.54       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00356     |
# |    std                  | 157         |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 700         |
# |    ep_rew_mean          | 10          |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 87          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.001237026 |
# |    clip_fraction        | 0.00264     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.5        |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.601       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.000208    |
# |    std                  | 163         |
# |    value_loss           | 20          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 706          |
# |    ep_rew_mean          | 8.43         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 88           |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0015472791 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.54        |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.88         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.000919     |
# |    std                  | 170          |
# |    value_loss           | 16           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 6.85         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 89           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0018615836 |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.58        |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.27        |
# |    n_updates            | 880          |
# |    policy_gradient_loss | 0.00118      |
# |    std                  | 178          |
# |    value_loss           | 14.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | 7.07        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 90          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.003123912 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.63       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.56        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.00258     |
# |    std                  | 189         |
# |    value_loss           | 11.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 5.74         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 91           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0019779522 |
# |    clip_fraction        | 0.00674      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.68        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.74         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -6.33e-05    |
# |    std                  | 198          |
# |    value_loss           | 23.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 716          |
# |    ep_rew_mean          | 3.2          |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 92           |
# |    time_elapsed         | 375          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0014620363 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.73        |
# |    explained_variance   | 0.822        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.74         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | 0.000177     |
# |    std                  | 206          |
# |    value_loss           | 33.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | 0.82        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 93          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.023268871 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.84       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -4.02       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00875     |
# |    std                  | 244         |
# |    value_loss           | 1.97        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 726          |
# |    ep_rew_mean          | -0.832       |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 94           |
# |    time_elapsed         | 383          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0032492196 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.94        |
# |    explained_variance   | 0.644        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.25        |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000249    |
# |    std                  | 258          |
# |    value_loss           | 7.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 734          |
# |    ep_rew_mean          | -3.72        |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 95           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0075069186 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.02        |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -3.5         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 283          |
# |    value_loss           | 3.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 744          |
# |    ep_rew_mean          | -6.7         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 96           |
# |    time_elapsed         | 391          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0103948545 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | 0.82         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -3.93        |
# |    n_updates            | 950          |
# |    policy_gradient_loss | 0.00373      |
# |    std                  | 316          |
# |    value_loss           | 2.23         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 751           |
# |    ep_rew_mean          | -9.5          |
# | time/                   |               |
# |    fps                  | 502           |
# |    iterations           | 97            |
# |    time_elapsed         | 395           |
# |    total_timesteps      | 198656        |
# | train/                  |               |
# |    approx_kl            | 0.00096226326 |
# |    clip_fraction        | 0.00186       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.19         |
# |    explained_variance   | 0.67          |
# |    learning_rate        | 0.0003        |
# |    loss                 | -3.26         |
# |    n_updates            | 960           |
# |    policy_gradient_loss | -4.4e-05      |
# |    std                  | 327           |
# |    value_loss           | 16.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 756         |
# |    ep_rew_mean          | -10.9       |
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 98          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.009623817 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.26       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -4.15       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.00344     |
# |    std                  | 363         |
# |    value_loss           | 2.29        |
# -----------------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.

# %% [markdown]
# ## I've been struggling with the code for several days and haven't been able to solve it. Sometimes it does go backward to gain momentum, but it doesn't make it all the way up. And when I increase the entropy, it does go up, but since it doesn't build up momentum, it doesn't reach the top. I understand that the goal is for it to go backward to gain speed and then climb up, but I haven’t managed to find that balance. I’ve tried several architectures, even a custom one, but haven’t gotten decent results. In the current simulation, it goes upward but never moves backward.

# %%
from stable_baselines3 import PPO
import torch

# Custom actor (pi) and value function (vf) networks
# of two layers of size 64 each with ReLU activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
policy_kwargs = dict(
    net_arch=dict(pi=[64, 64], vf=[64, 64]), activation_fn=torch.nn.ReLU
)

ent_coef = 0.8
learning_rate = 0.0002  # Experiment with different values
clip_range = 0.5  # Experiment with different values
# Create the agent
model = PPO("MlpPolicy", "MountainCarContinuous-v0", policy_kwargs=policy_kwargs, verbose=1, ent_coef=ent_coef, learning_rate=learning_rate, clip_range=clip_range)

# Retrieve the environment
env = model.get_env()

# Train the agent
model.learn(total_timesteps=200000)
# Out:
# Using cuda device
# Creating environment from the given name 'MountainCarContinuous-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -53.4    |
# | time/              |          |
# |    fps             | 849      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -53.8       |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006054082 |
# |    clip_fraction        | 0.00308     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -0.0312     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.15       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00937     |
# |    std                  | 1.08        |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -54.9       |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003777751 |
# |    clip_fraction        | 0.000928    |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -0.0531     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.25       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00813     |
# |    std                  | 1.15        |
# |    value_loss           | 0.0431      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -55.8        |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0032519987 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0.000375     |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.28        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 0.00849      |
# |    std                  | 1.23         |
# |    value_loss           | 0.0314       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -57          |
# | time/                   |              |
# |    fps                  | 550          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0035115154 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | 0.0125       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 0.00801      |
# |    std                  | 1.31         |
# |    value_loss           | 0.0283       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | -48.6        |
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 6            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0032229652 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | -0.0712      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.36        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 0.0088       |
# |    std                  | 1.39         |
# |    value_loss           | 0.0247       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 987          |
# |    ep_rew_mean          | -50.8        |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 7            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0014500314 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | -0.000956    |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.11        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00164     |
# |    std                  | 1.43         |
# |    value_loss           | 41.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 968         |
# |    ep_rew_mean          | -45.1       |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 8           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.033912756 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.288      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.43       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 1.53        |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 972         |
# |    ep_rew_mean          | -47.6       |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 9           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005940257 |
# |    clip_fraction        | 0.000488    |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.064       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 51.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000728   |
# |    std                  | 1.56        |
# |    value_loss           | 42.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 974         |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 10          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006911469 |
# |    clip_fraction        | 0.00449     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -0.493      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.54       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000194   |
# |    std                  | 1.67        |
# |    value_loss           | 0.132       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | -41.9        |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 11           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0052437973 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | -0.88        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00292      |
# |    std                  | 1.8          |
# |    value_loss           | 0.0534       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 900           |
# |    ep_rew_mean          | -31.4         |
# | time/                   |               |
# |    fps                  | 521           |
# |    iterations           | 12            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00072654383 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.5           |
# |    entropy_loss         | -2.02         |
# |    explained_variance   | 0.0771        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 79.5          |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000725     |
# |    std                  | 1.83          |
# |    value_loss           | 81.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 885           |
# |    ep_rew_mean          | -29.2         |
# | time/                   |               |
# |    fps                  | 523           |
# |    iterations           | 13            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00015066416 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.5           |
# |    entropy_loss         | -2.03         |
# |    explained_variance   | 0.187         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 13.7          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 2.13e-05      |
# |    std                  | 1.84          |
# |    value_loss           | 111           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 895          |
# |    ep_rew_mean          | -33.5        |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 14           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0010960392 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | 0.348        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.891       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -1.97e-05    |
# |    std                  | 1.87         |
# |    value_loss           | 32.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | -29          |
# | time/                   |              |
# |    fps                  | 519          |
# |    iterations           | 15           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0015692837 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.556       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 8.88e-05     |
# |    std                  | 1.93         |
# |    value_loss           | 2.45         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 873           |
# |    ep_rew_mean          | -22.9         |
# | time/                   |               |
# |    fps                  | 520           |
# |    iterations           | 16            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00044858994 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.5           |
# |    entropy_loss         | -2.08         |
# |    explained_variance   | 0.284         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 10.4          |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000199     |
# |    std                  | 1.95          |
# |    value_loss           | 67            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 862          |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 17           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0006920991 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.388        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 38.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000636    |
# |    std                  | 1.97         |
# |    value_loss           | 91.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 857          |
# |    ep_rew_mean          | -17.4        |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 18           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0045391647 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 30.2         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00415     |
# |    std                  | 1.99         |
# |    value_loss           | 65.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 864          |
# |    ep_rew_mean          | -16.7        |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 19           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0035595996 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 22.9         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00295     |
# |    std                  | 2.01         |
# |    value_loss           | 45.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 849          |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 519          |
# |    iterations           | 20           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0011474766 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.644        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 14.3         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00182     |
# |    std                  | 2.03         |
# |    value_loss           | 43.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 826         |
# |    ep_rew_mean          | -9.3        |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 21          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.001180534 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 4.74        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.000185   |
# |    std                  | 2.05        |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 833           |
# |    ep_rew_mean          | -12           |
# | time/                   |               |
# |    fps                  | 517           |
# |    iterations           | 22            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00019022758 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.5           |
# |    entropy_loss         | -2.14         |
# |    explained_variance   | 0.662         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 67.8          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000168     |
# |    std                  | 2.07          |
# |    value_loss           | 95.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 838          |
# |    ep_rew_mean          | -12.5        |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 23           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0007416924 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | -0.102       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.45         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -5.29e-05    |
# |    std                  | 2.1          |
# |    value_loss           | 17.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 823          |
# |    ep_rew_mean          | -9.01        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 24           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0006624676 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.531        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 14.6         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00034     |
# |    std                  | 2.15         |
# |    value_loss           | 28           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 822          |
# |    ep_rew_mean          | -8.49        |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 25           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0016964485 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 52           |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00108     |
# |    std                  | 2.17         |
# |    value_loss           | 68.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 815          |
# |    ep_rew_mean          | -7.54        |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 26           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0014526346 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 38.8         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 2.22         |
# |    value_loss           | 39           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 808          |
# |    ep_rew_mean          | -6.67        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 27           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0033759247 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 20.6         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000988    |
# |    std                  | 2.26         |
# |    value_loss           | 49.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 802          |
# |    ep_rew_mean          | -4.5         |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 28           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0011545441 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.742        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 39.2         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000322    |
# |    std                  | 2.31         |
# |    value_loss           | 41.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 794          |
# |    ep_rew_mean          | -2.26        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 29           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0010403655 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 19.3         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.000215     |
# |    std                  | 2.36         |
# |    value_loss           | 53.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 787         |
# |    ep_rew_mean          | 0.126       |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 30          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.018617488 |
# |    clip_fraction        | 0.00498     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 39.9        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00603    |
# |    std                  | 2.4         |
# |    value_loss           | 80.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 779         |
# |    ep_rew_mean          | 0.672       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 31          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010106275 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 37.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00273    |
# |    std                  | 2.45        |
# |    value_loss           | 84.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 785         |
# |    ep_rew_mean          | -1.51       |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 32          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011584833 |
# |    clip_fraction        | 0.00791     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 2.21        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00155    |
# |    std                  | 2.54        |
# |    value_loss           | 23          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 785          |
# |    ep_rew_mean          | -2.74        |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 33           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0015844869 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.0604       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 9.26         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.000767     |
# |    std                  | 2.62         |
# |    value_loss           | 32.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 771          |
# |    ep_rew_mean          | -0.134       |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 34           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0064180903 |
# |    clip_fraction        | 0.00332      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 29.2         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000172    |
# |    std                  | 2.74         |
# |    value_loss           | 31.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 774         |
# |    ep_rew_mean          | -0.813      |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 35          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003531465 |
# |    clip_fraction        | 0.000342    |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 51.6        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000608   |
# |    std                  | 2.83        |
# |    value_loss           | 87.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 779          |
# |    ep_rew_mean          | -2.7         |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 36           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0049861977 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 10           |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000207     |
# |    std                  | 2.99         |
# |    value_loss           | 20.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 783         |
# |    ep_rew_mean          | -3.4        |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 37          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014341052 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 4.93        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00551    |
# |    std                  | 3.17        |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 786         |
# |    ep_rew_mean          | -3.68       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 38          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010184357 |
# |    clip_fraction        | 0.00356     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 2.51        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000846   |
# |    std                  | 3.33        |
# |    value_loss           | 25.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | -1.28        |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 39           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0026562775 |
# |    clip_fraction        | 0.00103      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 8.42         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000467     |
# |    std                  | 3.51         |
# |    value_loss           | 24.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 777         |
# |    ep_rew_mean          | -1.97       |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 40          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.001289206 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 56.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00027    |
# |    std                  | 3.63        |
# |    value_loss           | 71.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 755        |
# |    ep_rew_mean          | 2.66       |
# | time/                   |            |
# |    fps                  | 512        |
# |    iterations           | 41         |
# |    time_elapsed         | 163        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01011825 |
# |    clip_fraction        | 0.00596    |
# |    clip_range           | 0.5        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | -0.682     |
# |    learning_rate        | 0.0002     |
# |    loss                 | 0.562      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.001     |
# |    std                  | 3.99       |
# |    value_loss           | 6.23       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 750          |
# |    ep_rew_mean          | 3.29         |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 42           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0009786674 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 39.9         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00022      |
# |    std                  | 4.09         |
# |    value_loss           | 62.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | 3.08         |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 43           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0052675107 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.0002       |
# |    loss                 | 18.6         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 4.23         |
# |    value_loss           | 30.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 745        |
# |    ep_rew_mean          | 4.5        |
# | time/                   |            |
# |    fps                  | 512        |
# |    iterations           | 44         |
# |    time_elapsed         | 175        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01498335 |
# |    clip_fraction        | 0.00845    |
# |    clip_range           | 0.5        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 19         |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00314   |
# |    std                  | 4.42       |
# |    value_loss           | 22.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 740          |
# |    ep_rew_mean          | 5.51         |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 45           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0008737994 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 37           |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000299     |
# |    std                  | 4.53         |
# |    value_loss           | 60.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 733          |
# |    ep_rew_mean          | 7.45         |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 46           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0033673362 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 48.3         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000398    |
# |    std                  | 4.67         |
# |    value_loss           | 52.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 732          |
# |    ep_rew_mean          | 6.07         |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 47           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0012731032 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 13.6         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.000381     |
# |    std                  | 4.84         |
# |    value_loss           | 39.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 736         |
# |    ep_rew_mean          | 4.44        |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 48          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004141851 |
# |    clip_fraction        | 0.00083     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 14          |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00104    |
# |    std                  | 5           |
# |    value_loss           | 53.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 735         |
# |    ep_rew_mean          | 4.99        |
# | time/                   |             |
# |    fps                  | 511         |
# |    iterations           | 49          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.020107402 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 24.5        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00361    |
# |    std                  | 5.25        |
# |    value_loss           | 32.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 734          |
# |    ep_rew_mean          | 5.67         |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 50           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0019027642 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 13.6         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000451    |
# |    std                  | 5.47         |
# |    value_loss           | 40.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 734         |
# |    ep_rew_mean          | 4.32        |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 51          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.006238763 |
# |    clip_fraction        | 0.00308     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 2.28        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.000601    |
# |    std                  | 5.79        |
# |    value_loss           | 24.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 726          |
# |    ep_rew_mean          | 5.61         |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 52           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0018418306 |
# |    clip_fraction        | 9.77e-05     |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 752          |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 82           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0020055103 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 1.16         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.000121     |
# |    std                  | 17.8         |
# |    value_loss           | 25.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 747          |
# |    ep_rew_mean          | -8.23        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 83           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0017223079 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | 0.756        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 15.8         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.000143    |
# |    std                  | 18.4         |
# |    value_loss           | 48.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 751         |
# |    ep_rew_mean          | -8.65       |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 84          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.001415484 |
# |    clip_fraction        | 4.88e-05    |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 15.2        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -5.96e-05   |
# |    std                  | 19.1        |
# |    value_loss           | 35          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 752          |
# |    ep_rew_mean          | -7.93        |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 85           |
# |    time_elapsed         | 340          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0022901506 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.6         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | 0.00108      |
# |    std                  | 20.1         |
# |    value_loss           | 21.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 756          |
# |    ep_rew_mean          | -9.35        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 86           |
# |    time_elapsed         | 344          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0026576412 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.43        |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0002       |
# |    loss                 | 12.5         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.000653    |
# |    std                  | 20.7         |
# |    value_loss           | 61.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 748          |
# |    ep_rew_mean          | -8.67        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 87           |
# |    time_elapsed         | 348          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0055325087 |
# |    clip_fraction        | 0.00166      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0192      |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 0.000963     |
# |    std                  | 22.4         |
# |    value_loss           | 8.47         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | -10.4        |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 88           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0047326754 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.56        |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.65        |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000108    |
# |    std                  | 23.7         |
# |    value_loss           | 14.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | -11.8        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 89           |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0049061696 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 0.764        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 24.4         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 24.5         |
# |    value_loss           | 31.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 756         |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 90          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.003564068 |
# |    clip_fraction        | 0.000928    |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.14       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.000189    |
# |    std                  | 26.2        |
# |    value_loss           | 9.6         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 759          |
# |    ep_rew_mean          | -11.1        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 91           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0029547373 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.71        |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.71        |
# |    n_updates            | 900          |
# |    policy_gradient_loss | 0.000417     |
# |    std                  | 27.6         |
# |    value_loss           | 17.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 761           |
# |    ep_rew_mean          | -11.3         |
# | time/                   |               |
# |    fps                  | 510           |
# |    iterations           | 92            |
# |    time_elapsed         | 368           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00081133447 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.5           |
# |    entropy_loss         | -4.75         |
# |    explained_variance   | 0.886         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 21.7          |
# |    n_updates            | 910           |
# |    policy_gradient_loss | 0.000437      |
# |    std                  | 28.4          |
# |    value_loss           | 38.9          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 759         |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 93          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.001850726 |
# |    clip_fraction        | 0.000293    |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.136      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.000217    |
# |    std                  | 29.7        |
# |    value_loss           | 22.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 757          |
# |    ep_rew_mean          | -12          |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 94           |
# |    time_elapsed         | 376          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0016204494 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.83        |
# |    explained_variance   | 0.79         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 18.8         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 0.00117      |
# |    std                  | 31           |
# |    value_loss           | 27.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | -11.7        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 95           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0025124399 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.88        |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 14.1         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.000337     |
# |    std                  | 32.6         |
# |    value_loss           | 20.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | -12.9        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 96           |
# |    time_elapsed         | 385          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0024501116 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 8.29         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.000633    |
# |    std                  | 34.3         |
# |    value_loss           | 21.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 97          |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.004697781 |
# |    clip_fraction        | 0.00166     |
# |    clip_range           | 0.5         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 9.96        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 36.5        |
# |    value_loss           | 15.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 756          |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 98           |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0030514663 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.5          |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 6.46         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 0.0002       |
# |    std                  | 38.7         |
# |    value_loss           | 14.5         |
# ------------------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.

# %%
from stable_baselines3 import PPO
import torch

# Custom actor (pi) and value function (vf) networks
# of two layers of size 64 each with ReLU activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
policy_kwargs = dict(
    net_arch=dict(pi=[64, 64], vf=[64, 64]), activation_fn=torch.nn.ReLU
)

ent_coef = 0.8
learning_rate = 0.0002  # Experiment with different values
clip_range = 0.2  # Experiment with different values
# Create the agent
model = PPO("MlpPolicy", "MountainCarContinuous-v0", policy_kwargs=policy_kwargs, verbose=1, ent_coef=ent_coef, learning_rate=learning_rate, clip_range=clip_range)

# Retrieve the environment
env = model.get_env()

# Train the agent
model.learn(total_timesteps=200000)
# Out:
# Using cuda device
# Creating environment from the given name 'MountainCarContinuous-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -51.4    |
# | time/              |          |
# |    fps             | 842      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -53.3       |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004764479 |
# |    clip_fraction        | 0.0176      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -0.157      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.18       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00859     |
# |    std                  | 1.08        |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -54.7       |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004393584 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | -0.0296     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.24       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00878     |
# |    std                  | 1.15        |
# |    value_loss           | 0.0669      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -55.8       |
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003974234 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | -0.00269    |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.27       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00711     |
# |    std                  | 1.23        |
# |    value_loss           | 0.0419      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 966          |
# |    ep_rew_mean          | -45.1        |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0030486502 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.66        |
# |    explained_variance   | -0.0171      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.33        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 0.00852      |
# |    std                  | 1.31         |
# |    value_loss           | 0.0314       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 972           |
# |    ep_rew_mean          | -48           |
# | time/                   |               |
# |    fps                  | 534           |
# |    iterations           | 6             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00094416295 |
# |    clip_fraction        | 0.00186       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.7          |
# |    explained_variance   | -0.00795      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.298         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 0.00076       |
# |    std                  | 1.35          |
# |    value_loss           | 40.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 976          |
# |    ep_rew_mean          | -50.3        |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 7            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0054232758 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.00943      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.37        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000163    |
# |    std                  | 1.45         |
# |    value_loss           | 0.174        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 979         |
# |    ep_rew_mean          | -52.3       |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 8           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004074394 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -0.581      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.45       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00208     |
# |    std                  | 1.56        |
# |    value_loss           | 0.0825      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 981          |
# |    ep_rew_mean          | -54          |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 9            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0038574454 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | -0.332       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.53        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.00734      |
# |    std                  | 1.66         |
# |    value_loss           | 0.0285       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 983          |
# |    ep_rew_mean          | -55.8        |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 10           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0038632369 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | -0.305       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.57        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.00528      |
# |    std                  | 1.78         |
# |    value_loss           | 0.0253       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | -57.3        |
# | time/                   |              |
# |    fps                  | 528          |
# |    iterations           | 11           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0034065982 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | -0.34        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.64        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00541      |
# |    std                  | 1.9          |
# |    value_loss           | 0.0257       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | -58.6        |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 12           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0039061203 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | -0.454       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.68        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00587      |
# |    std                  | 2.02         |
# |    value_loss           | 0.0183       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | -56.1       |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 13          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003618169 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -0.107      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.73       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.0065      |
# |    std                  | 2.16        |
# |    value_loss           | 0.0158      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 979           |
# |    ep_rew_mean          | -57.4         |
# | time/                   |               |
# |    fps                  | 523           |
# |    iterations           | 14            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00030072161 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.2          |
# |    explained_variance   | 0.0299        |
# |    learning_rate        | 0.0002        |
# |    loss                 | -0.0552       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | 0.000374      |
# |    std                  | 2.2           |
# |    value_loss           | 43            |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 980         |
# |    ep_rew_mean          | -58.7       |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 15          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003609179 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | -0.206      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.66       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000539   |
# |    std                  | 2.34        |
# |    value_loss           | 0.245       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 981         |
# |    ep_rew_mean          | -60         |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 16          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004384885 |
# |    clip_fraction        | 0.0194      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | -0.779      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.85       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00119     |
# |    std                  | 2.52        |
# |    value_loss           | 0.0467      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 982         |
# |    ep_rew_mean          | -61.1       |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 17          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004248512 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.91       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00323     |
# |    std                  | 2.7         |
# |    value_loss           | 0.0326      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 983          |
# |    ep_rew_mean          | -62.1        |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 18           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0044567743 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | -0.257       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.96        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.00431      |
# |    std                  | 2.88         |
# |    value_loss           | 0.0253       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | -63.2        |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 19           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0046415683 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | -0.394       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.02        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.0043       |
# |    std                  | 3.08         |
# |    value_loss           | 0.0155       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | -64.1        |
# | time/                   |              |
# |    fps                  | 519          |
# |    iterations           | 20           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0036799128 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | -0.0442      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.08        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00381      |
# |    std                  | 3.29         |
# |    value_loss           | 0.013        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 983          |
# |    ep_rew_mean          | -62.6        |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 21           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0036940654 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.0161       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.1         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.00447      |
# |    std                  | 3.52         |
# |    value_loss           | 0.00892      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 979           |
# |    ep_rew_mean          | -61.4         |
# | time/                   |               |
# |    fps                  | 517           |
# |    iterations           | 22            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00026593325 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.69         |
# |    explained_variance   | 0.0276        |
# |    learning_rate        | 0.0002        |
# |    loss                 | -1.54         |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000255     |
# |    std                  | 3.58          |
# |    value_loss           | 41.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 980          |
# |    ep_rew_mean          | -62.5        |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 23           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0019007947 |
# |    clip_fraction        | 0.00513      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.99        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000149    |
# |    std                  | 3.72         |
# |    value_loss           | 29.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 976         |
# |    ep_rew_mean          | -61.1       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 24          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005395556 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | -0.484      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.23       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00483     |
# |    std                  | 4           |
# |    value_loss           | 0.0142      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 977           |
# |    ep_rew_mean          | -62.1         |
# | time/                   |               |
# |    fps                  | 516           |
# |    iterations           | 25            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00025450668 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.314         |
# |    learning_rate        | 0.0002        |
# |    loss                 | -0.944        |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00051      |
# |    std                  | 4.07          |
# |    value_loss           | 33.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 975          |
# |    ep_rew_mean          | -60.9        |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 26           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0026304685 |
# |    clip_fraction        | 0.00796      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.543       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.97        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 4.25         |
# |    value_loss           | 1.09         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 971          |
# |    ep_rew_mean          | -59.7        |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 27           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0004589986 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 45           |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000612    |
# |    std                  | 4.3          |
# |    value_loss           | 42           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | -59.2       |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 28          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.000372063 |
# |    clip_fraction        | 0.000391    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 100         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000111   |
# |    std                  | 4.38        |
# |    value_loss           | 36          |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 967           |
# |    ep_rew_mean          | -58.1         |
# | time/                   |               |
# |    fps                  | 516           |
# |    iterations           | 29            |
# |    time_elapsed         | 114           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00041760577 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.9          |
# |    explained_variance   | 0.392         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.72          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000917     |
# |    std                  | 4.43          |
# |    value_loss           | 36.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 966           |
# |    ep_rew_mean          | -57.4         |
# | time/                   |               |
# |    fps                  | 516           |
# |    iterations           | 30            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00053639105 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.91         |
# |    explained_variance   | 0.252         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.12          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.0016       |
# |    std                  | 4.49          |
# |    value_loss           | 45.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 967          |
# |    ep_rew_mean          | -58.4        |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 31           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0011383812 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.388        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 53.2         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000379    |
# |    std                  | 4.58         |
# |    value_loss           | 35.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -56.2        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 32           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0066612456 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.97        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.00108      |
# |    std                  | 4.99         |
# |    value_loss           | 0.512        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 964           |
# |    ep_rew_mean          | -57.2         |
# | time/                   |               |
# |    fps                  | 515           |
# |    iterations           | 33            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00059376354 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.03         |
# |    explained_variance   | 0.504         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 14.8          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000758     |
# |    std                  | 5.06          |
# |    value_loss           | 51.2          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | -56.6       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 34          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004657846 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | -0.682      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.18       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00054    |
# |    std                  | 5.45        |
# |    value_loss           | 0.789       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 964           |
# |    ep_rew_mean          | -57.5         |
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 35            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00028765312 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.12         |
# |    explained_variance   | 0.361         |
# |    learning_rate        | 0.0002        |
# |    loss                 | -2.02         |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 0.000251      |
# |    std                  | 5.55          |
# |    value_loss           | 37.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 958          |
# |    ep_rew_mean          | -55.1        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 36           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0030644052 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | -0.377       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.27        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000565     |
# |    std                  | 5.89         |
# |    value_loss           | 1.25         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | -56.1         |
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 37            |
# |    time_elapsed         | 147           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00017122211 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.2          |
# |    explained_variance   | 0.327         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 36.1          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | 3.15e-05      |
# |    std                  | 5.96          |
# |    value_loss           | 69            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | -55.7        |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 38           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0061187455 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | -0.522       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.33        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0018      |
# |    std                  | 6.36         |
# |    value_loss           | 1.13         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 956           |
# |    ep_rew_mean          | -56.5         |
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 39            |
# |    time_elapsed         | 155           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00046660515 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.28         |
# |    explained_variance   | 0.385         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.82          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -4.83e-05     |
# |    std                  | 6.51          |
# |    value_loss           | 31.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -57.4       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 40          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012213055 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | -1.26       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.68       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00341     |
# |    std                  | 7.3         |
# |    value_loss           | 0.0845      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -57         |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 41          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008046492 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | -0.119      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.79       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00331     |
# |    std                  | 8.06        |
# |    value_loss           | 0.0368      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 958           |
# |    ep_rew_mean          | -56.7         |
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 42            |
# |    time_elapsed         | 167           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00019701454 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.51         |
# |    explained_variance   | 0.448         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 10.7          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.00013      |
# |    std                  | 8.17          |
# |    value_loss           | 31            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 959           |
# |    ep_rew_mean          | -57.5         |
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 43            |
# |    time_elapsed         | 171           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00016184917 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.52         |
# |    explained_variance   | 0.492         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 12.6          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000119     |
# |    std                  | 8.25          |
# |    value_loss           | 33.6          |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | -57.2      |
# | time/                   |            |
# |    fps                  | 513        |
# |    iterations           | 44         |
# |    time_elapsed         | 175        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00563706 |
# |    clip_fraction        | 0.0184     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | -0.87      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -2.83      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.000995   |
# |    std                  | 8.88       |
# |    value_loss           | 0.211      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 950          |
# |    ep_rew_mean          | -54.2        |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 45           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0003197516 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.61        |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 6.62         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000532    |
# |    std                  | 9.05         |
# |    value_loss           | 15.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 952           |
# |    ep_rew_mean          | -54.4         |
# | time/                   |               |
# |    fps                  | 512           |
# |    iterations           | 46            |
# |    time_elapsed         | 183           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 4.1897933e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.62         |
# |    explained_variance   | 0.546         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 31.8          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 4.57e-05      |
# |    std                  | 9.09          |
# |    value_loss           | 89.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 948           |
# |    ep_rew_mean          | -53.9         |
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 47            |
# |    time_elapsed         | 187           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00054939254 |
# |    clip_fraction        | 0.000635      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.63         |
# |    explained_variance   | 0.627         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 12.7          |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000127     |
# |    std                  | 9.21          |
# |    value_loss           | 25.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 938           |
# |    ep_rew_mean          | -52.1         |
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 48            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 7.0226524e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.64         |
# |    explained_variance   | 0.446         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 4.2           |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 6.91e-05      |
# |    std                  | 9.26          |
# |    value_loss           | 59.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | -50.8        |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 49           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0005873671 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.65        |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 4.93         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000542    |
# |    std                  | 9.37         |
# |    value_loss           | 24.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 935           |
# |    ep_rew_mean          | -51.5         |
# | time/                   |               |
# |    fps                  | 512           |
# |    iterations           | 50            |
# |    time_elapsed         | 199           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00032680022 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.66         |
# |    explained_variance   | 0.567         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 23.4          |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.00062      |
# |    std                  | 9.44          |
# |    value_loss           | 84            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 931           |
# |    ep_rew_mean          | -50.8         |
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 51            |
# |    time_elapsed         | 203           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00023012928 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.67         |
# |    explained_variance   | 0.711         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.77          |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 0.000124      |
# |    std                  | 9.58          |
# |    value_loss           | 25.7          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# ...
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 82           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 8.734391e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.69        |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 17.3         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -2.66e-05    |
# |    std                  | 26.3         |
# |    value_loss           | 51.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 805         |
# |    ep_rew_mean          | -21.8       |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 83          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.008226931 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -3.16       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00364    |
# |    std                  | 27.6        |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 808           |
# |    ep_rew_mean          | -24.1         |
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 84            |
# |    time_elapsed         | 338           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00015475793 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.74         |
# |    explained_variance   | 0.762         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 2.23          |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.00021      |
# |    std                  | 27.9          |
# |    value_loss           | 26.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 799           |
# |    ep_rew_mean          | -21.4         |
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 85            |
# |    time_elapsed         | 342           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.00026872795 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.76         |
# |    explained_variance   | 0.805         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 6.14          |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -3.65e-05     |
# |    std                  | 28.4          |
# |    value_loss           | 15.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 800          |
# |    ep_rew_mean          | -22.6        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 86           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0002100039 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.77        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2            |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -7.19e-05    |
# |    std                  | 28.8         |
# |    value_loss           | 22.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | -21.5        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 87           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0005423812 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 6.42         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00065     |
# |    std                  | 29.3         |
# |    value_loss           | 23.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 798          |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 88           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0002605586 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.8         |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 10.9         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000215    |
# |    std                  | 29.7         |
# |    value_loss           | 43           |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 800           |
# |    ep_rew_mean          | -21.8         |
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 89            |
# |    time_elapsed         | 359           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00045967405 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.82         |
# |    explained_variance   | 0.823         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 10.8          |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.000944     |
# |    std                  | 30.2          |
# |    value_loss           | 36.7          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 801         |
# |    ep_rew_mean          | -22.9       |
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 90          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.005184412 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.7        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.000728    |
# |    std                  | 32.4        |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 802           |
# |    ep_rew_mean          | -24.1         |
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 91            |
# |    time_elapsed         | 366           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00066416385 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.91         |
# |    explained_variance   | 0.875         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 2.16          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | 0.000852      |
# |    std                  | 33.3          |
# |    value_loss           | 15            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 796           |
# |    ep_rew_mean          | -22.6         |
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 92            |
# |    time_elapsed         | 370           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00050318753 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.94         |
# |    explained_variance   | 0.89          |
# |    learning_rate        | 0.0002        |
# |    loss                 | 4.12          |
# |    n_updates            | 910           |
# |    policy_gradient_loss | 0.00032       |
# |    std                  | 34.1          |
# |    value_loss           | 21.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 796           |
# |    ep_rew_mean          | -22.7         |
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 93            |
# |    time_elapsed         | 375           |
# |    total_timesteps      | 190464        |
# | train/                  |               |
# |    approx_kl            | 0.00026375856 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.96         |
# |    explained_variance   | 0.859         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 17.6          |
# |    n_updates            | 920           |
# |    policy_gradient_loss | 0.000314      |
# |    std                  | 34.7          |
# |    value_loss           | 45            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 798          |
# |    ep_rew_mean          | -23.9        |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 94           |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0071120257 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.01        |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -3.25        |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 0.000582     |
# |    std                  | 37.8         |
# |    value_loss           | 2.69         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 792         |
# |    ep_rew_mean          | -22.4       |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 95          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.009645259 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -3.56       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.000902   |
# |    std                  | 41.9        |
# |    value_loss           | 1.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 794          |
# |    ep_rew_mean          | -22.6        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 96           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0003109941 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.16        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 15.6         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.000807    |
# |    std                  | 42.5         |
# |    value_loss           | 35           |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 793           |
# |    ep_rew_mean          | -22.6         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 97            |
# |    time_elapsed         | 390           |
# |    total_timesteps      | 198656        |
# | train/                  |               |
# |    approx_kl            | 0.00055811333 |
# |    clip_fraction        | 0.000635      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.18         |
# |    explained_variance   | 0.849         |
# |    learning_rate        | 0.0002        |
# |    loss                 | -1.79         |
# |    n_updates            | 960           |
# |    policy_gradient_loss | 0.000229      |
# |    std                  | 43.6          |
# |    value_loss           | 12.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | -24.3        |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 98           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0006491805 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.2         |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.17        |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 1.97e-05     |
# |    std                  | 44.6         |
# |    value_loss           | 16.6         |
# ------------------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.

# %%
from stable_baselines3 import PPO
import torch

# Custom actor (pi) and value function (vf) networks
# of two layers of size 64 each with ReLU activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
policy_kwargs = dict(
    net_arch=dict(pi=[64, 64], vf=[64, 64]), activation_fn=torch.nn.ReLU
)

ent_coef = 0.8
learning_rate = 0.0002  # Experiment with different values
clip_range = 0.8  # Experiment with different values
# Create the agent
model = PPO("MlpPolicy", "MountainCarContinuous-v0", policy_kwargs=policy_kwargs, verbose=1, ent_coef=ent_coef, learning_rate=learning_rate, clip_range=clip_range)

# Retrieve the environment
env = model.get_env()

# Train the agent
model.learn(total_timesteps=200000)
# Out:
# Using cuda device
# Creating environment from the given name 'MountainCarContinuous-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -50.9    |
# | time/              |          |
# |    fps             | 845      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -53        |
# | time/                   |            |
# |    fps                  | 636        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00519888 |
# |    clip_fraction        | 0.000391   |
# |    clip_range           | 0.8        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | -0.0679    |
# |    learning_rate        | 0.0002     |
# |    loss                 | -1.18      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.00896    |
# |    std                  | 1.08       |
# |    value_loss           | 0.195      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005250322 |
# |    clip_fraction        | 0.000391    |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -0.0469     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.22       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00833     |
# |    std                  | 1.15        |
# |    value_loss           | 0.0671      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -55.7        |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0064002145 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | -0.0509      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.26        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 0.00638      |
# |    std                  | 1.23         |
# |    value_loss           | 0.0418       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -56.9        |
# | time/                   |              |
# |    fps                  | 553          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0035540608 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -1.66        |
# |    explained_variance   | -0.0125      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.34        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 0.00778      |
# |    std                  | 1.31         |
# |    value_loss           | 0.0325       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -57.9        |
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 6            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0032938034 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.0207       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.38        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 0.00786      |
# |    std                  | 1.4          |
# |    value_loss           | 0.0293       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -58.8        |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 7            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0034856717 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | -0.0122      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.43        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 0.00766      |
# |    std                  | 1.49         |
# |    value_loss           | 0.0214       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.9        |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 8            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0036882227 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | -0.00586     |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.47        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.00621      |
# |    std                  | 1.59         |
# |    value_loss           | 0.0201       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -61          |
# | time/                   |              |
# |    fps                  | 529          |
# |    iterations           | 9            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0046877633 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.0785       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.52        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.0065       |
# |    std                  | 1.69         |
# |    value_loss           | 0.0182       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -62         |
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 10          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004614817 |
# |    clip_fraction        | 0.000684    |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.00111     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.57       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00606     |
# |    std                  | 1.8         |
# |    value_loss           | 0.0188      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -62.9        |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 11           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0032122864 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | -0.0449      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.63        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00602      |
# |    std                  | 1.92         |
# |    value_loss           | 0.0166       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 994          |
# |    ep_rew_mean          | -59.3        |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 12           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0031631887 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | -0.0138      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.68        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00695      |
# |    std                  | 2.04         |
# |    value_loss           | 0.0166       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 994           |
# |    ep_rew_mean          | -60.4         |
# | time/                   |               |
# |    fps                  | 525           |
# |    iterations           | 13            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00064727745 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.15         |
# |    explained_variance   | 0.00413       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 23.5          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00137      |
# |    std                  | 2.09          |
# |    value_loss           | 44.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | -58.2        |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 14           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0075837714 |
# |    clip_fraction        | 0.00107      |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | -0.155       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.76        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00095     |
# |    std                  | 2.24         |
# |    value_loss           | 0.12         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 983           |
# |    ep_rew_mean          | -52.4         |
# | time/                   |               |
# |    fps                  | 522           |
# |    iterations           | 15            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00084493315 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.24         |
# |    explained_variance   | 0.0755        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 19.8          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -8.73e-05     |
# |    std                  | 2.29          |
# |    value_loss           | 41.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 973          |
# |    ep_rew_mean          | -50.2        |
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 16           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0002474242 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 64.1         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 2.43e-05     |
# |    std                  | 2.32         |
# |    value_loss           | 73           |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 970           |
# |    ep_rew_mean          | -48.6         |
# | time/                   |               |
# |    fps                  | 523           |
# |    iterations           | 17            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00036603396 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.27         |
# |    explained_variance   | 0.243         |
# |    learning_rate        | 0.0002        |
# |    loss                 | -0.0269       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00047      |
# |    std                  | 2.35          |
# |    value_loss           | 42.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 972          |
# |    ep_rew_mean          | -50.1        |
# | time/                   |              |
# |    fps                  | 519          |
# |    iterations           | 18           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0004309625 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.941       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -2.48e-05    |
# |    std                  | 2.38         |
# |    value_loss           | 40.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 958          |
# |    ep_rew_mean          | -48.5        |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 19           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0059759193 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | -0.914       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.57        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000821    |
# |    std                  | 2.53         |
# |    value_loss           | 0.884        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | -49.9         |
# | time/                   |               |
# |    fps                  | 522           |
# |    iterations           | 20            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00076954876 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.36         |
# |    explained_variance   | 0.18          |
# |    learning_rate        | 0.0002        |
# |    loss                 | 55            |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000614     |
# |    std                  | 2.59          |
# |    value_loss           | 38.7          |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 956        |
# |    ep_rew_mean          | -47.1      |
# | time/                   |            |
# |    fps                  | 520        |
# |    iterations           | 21         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02078313 |
# |    clip_fraction        | 0.00703    |
# |    clip_range           | 0.8        |
# |    entropy_loss         | -2.42      |
# |    explained_variance   | -0.388     |
# |    learning_rate        | 0.0002     |
# |    loss                 | -1.91      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.00092    |
# |    std                  | 2.85       |
# |    value_loss           | 0.104      |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 957           |
# |    ep_rew_mean          | -48.6         |
# | time/                   |               |
# |    fps                  | 521           |
# |    iterations           | 22            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00020857932 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.47         |
# |    explained_variance   | 0.235         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 61.6          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | 4.95e-05      |
# |    std                  | 2.88          |
# |    value_loss           | 75.1          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | -47.7       |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 23          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003548528 |
# |    clip_fraction        | 0.000293    |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | -0.125      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.85       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000926    |
# |    std                  | 3.05        |
# |    value_loss           | 0.879       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 940           |
# |    ep_rew_mean          | -42.5         |
# | time/                   |               |
# |    fps                  | 520           |
# |    iterations           | 24            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00031122123 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.54         |
# |    explained_variance   | 0.277         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.15          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 4.18e-05      |
# |    std                  | 3.1           |
# |    value_loss           | 35.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 936           |
# |    ep_rew_mean          | -41.8         |
# | time/                   |               |
# |    fps                  | 519           |
# |    iterations           | 25            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00020584647 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.56         |
# |    explained_variance   | 0.351         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 25.5          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000413     |
# |    std                  | 3.13          |
# |    value_loss           | 98.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | -43.3        |
# | time/                   |              |
# |    fps                  | 520          |
# |    iterations           | 26           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0007156196 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 35.9         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000648    |
# |    std                  | 3.18         |
# |    value_loss           | 27.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 941         |
# |    ep_rew_mean          | -44.8       |
# | time/                   |             |
# |    fps                  | 519         |
# |    iterations           | 27          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.033293016 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | -1.38       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.93       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00459    |
# |    std                  | 3.41        |
# |    value_loss           | 0.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 940         |
# |    ep_rew_mean          | -45.1       |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 28          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010727756 |
# |    clip_fraction        | 0.000635    |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | -0.238      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.37       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00151    |
# |    std                  | 3.61        |
# |    value_loss           | 1.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 918         |
# |    ep_rew_mean          | -40.3       |
# | time/                   |             |
# |    fps                  | 519         |
# |    iterations           | 29          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011703512 |
# |    clip_fraction        | 0.00181     |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 13.8        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00243    |
# |    std                  | 3.72        |
# |    value_loss           | 36.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 921          |
# |    ep_rew_mean          | -41.8        |
# | time/                   |              |
# |    fps                  | 520          |
# |    iterations           | 30           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0016264518 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.393        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 50.1         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000774    |
# |    std                  | 3.75         |
# |    value_loss           | 91.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 919         |
# |    ep_rew_mean          | -42         |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 31          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010528572 |
# |    clip_fraction        | 0.00337     |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | -0.594      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.97       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00084     |
# |    std                  | 4.05        |
# |    value_loss           | 0.892       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -39.9         |
# | time/                   |               |
# |    fps                  | 519           |
# |    iterations           | 32            |
# |    time_elapsed         | 126           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00028256903 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0.417         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 41.2          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | 0.00055       |
# |    std                  | 4.12          |
# |    value_loss           | 32.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 909          |
# |    ep_rew_mean          | -39.8        |
# | time/                   |              |
# |    fps                  | 519          |
# |    iterations           | 33           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 9.160669e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.52         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 42.5         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.000163     |
# |    std                  | 4.17         |
# |    value_loss           | 59.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -38         |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 34          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.000643405 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.842      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000151   |
# |    std                  | 4.24        |
# |    value_loss           | 38.1        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 890           |
# |    ep_rew_mean          | -36.3         |
# | time/                   |               |
# |    fps                  | 518           |
# |    iterations           | 35            |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00018614333 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.535         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 20.2          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 0.000387      |
# |    std                  | 4.29          |
# |    value_loss           | 49.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 884           |
# |    ep_rew_mean          | -36.3         |
# | time/                   |               |
# |    fps                  | 519           |
# |    iterations           | 36            |
# |    time_elapsed         | 142           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00022123154 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0.65          |
# |    learning_rate        | 0.0002        |
# |    loss                 | 25.6          |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 0.000119      |
# |    std                  | 4.35          |
# |    value_loss           | 44            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 882          |
# |    ep_rew_mean          | -36          |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 37           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0018555942 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.504       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000748    |
# |    std                  | 4.46         |
# |    value_loss           | 23           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 878          |
# |    ep_rew_mean          | -34.9        |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 38           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0009593958 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 17.9         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000197    |
# |    std                  | 4.55         |
# |    value_loss           | 32.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 878           |
# |    ep_rew_mean          | -35.2         |
# | time/                   |               |
# |    fps                  | 518           |
# |    iterations           | 39            |
# |    time_elapsed         | 154           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00055706647 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -2.94         |
# |    explained_variance   | 0.707         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 9.55          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 0.000335      |
# |    std                  | 4.62          |
# |    value_loss           | 50.9          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 876         |
# |    ep_rew_mean          | -34.9       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 40          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.001961177 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 11.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000407   |
# |    std                  | 4.77        |
# |    value_loss           | 23.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 874          |
# |    ep_rew_mean          | -34.1        |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 41           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0012472984 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -2.99        |
# |    explained_variance   | 0.608        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 25.5         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000471    |
# |    std                  | 4.88         |
# |    value_loss           | 40.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 877         |
# |    ep_rew_mean          | -35.3       |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 42          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.002291774 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 10.3        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 4.97        |
# |    value_loss           | 65.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 867         |
# |    ep_rew_mean          | -33.8       |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 43          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.031466138 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.786       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00518    |
# |    std                  | 5.21        |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 861         |
# |    ep_rew_mean          | -32.4       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 44          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003116437 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 10.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000256   |
# |    std                  | 5.34        |
# |    value_loss           | 46.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 850          |
# |    ep_rew_mean          | -30.5        |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 45           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0064669396 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 23.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00053     |
# |    std                  | 5.5          |
# |    value_loss           | 34           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 840          |
# |    ep_rew_mean          | -28.6        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 46           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0022657833 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 26           |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000883    |
# |    std                  | 5.68         |
# |    value_loss           | 42.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | -26.9       |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 47          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.012550462 |
# |    clip_fraction        | 0.000439    |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 6.1         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00228    |
# |    std                  | 5.89        |
# |    value_loss           | 34.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 836          |
# |    ep_rew_mean          | -26.5        |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 48           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0019439396 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.587        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 32.8         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000173    |
# |    std                  | 6.04         |
# |    value_loss           | 68.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 830          |
# |    ep_rew_mean          | -25.7        |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 49           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0028286087 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 5.57         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 6.26         |
# |    value_loss           | 38.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 824         |
# |    ep_rew_mean          | -23.8       |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 50          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.002041172 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 33.3        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.000101    |
# |    std                  | 6.58        |
# |    value_loss           | 28.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 811          |
# |    ep_rew_mean          | -21.2        |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 51           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0012025593 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.753        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 7.95         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.000849     |
# |    std                  | 6.8          |
# |    value_loss           | 45           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 511         |
# |    iterations           | 52          |
# |    time_elapsed         | 208         |
# ...
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 82           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0003922579 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.45        |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 5.46         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.000214    |
# |    std                  | 20.9         |
# |    value_loss           | 28.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 805           |
# |    ep_rew_mean          | -25.1         |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 83            |
# |    time_elapsed         | 333           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 0.00020002449 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -4.47         |
# |    explained_variance   | 0.802         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 1.48          |
# |    n_updates            | 820           |
# |    policy_gradient_loss | 0.000346      |
# |    std                  | 21.2          |
# |    value_loss           | 21.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 803         |
# |    ep_rew_mean          | -24         |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 84          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.005643067 |
# |    clip_fraction        | 0.000342    |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -3.01       |
# |    n_updates            | 830         |
# |    policy_gradient_loss | 0.00022     |
# |    std                  | 22.9        |
# |    value_loss           | 2.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 809          |
# |    ep_rew_mean          | -25.6        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 85           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0005594108 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.56        |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 16           |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 23.2         |
# |    value_loss           | 29           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 815          |
# |    ep_rew_mean          | -27.2        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 86           |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0005915871 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.57        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.51         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.000227    |
# |    std                  | 23.8         |
# |    value_loss           | 16.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 814           |
# |    ep_rew_mean          | -29.2         |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 87            |
# |    time_elapsed         | 350           |
# |    total_timesteps      | 178176        |
# | train/                  |               |
# |    approx_kl            | 0.00031780853 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -4.6          |
# |    explained_variance   | 0.815         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 18.9          |
# |    n_updates            | 860           |
# |    policy_gradient_loss | 0.00027       |
# |    std                  | 24.2          |
# |    value_loss           | 21.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 810          |
# |    ep_rew_mean          | -27.9        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 88           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0005966674 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.62        |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.385       |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000234    |
# |    std                  | 24.8         |
# |    value_loss           | 16.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 809           |
# |    ep_rew_mean          | -27.8         |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 89            |
# |    time_elapsed         | 357           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00058810075 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -4.64         |
# |    explained_variance   | 0.868         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.0972        |
# |    n_updates            | 880           |
# |    policy_gradient_loss | 0.000171      |
# |    std                  | 25.4          |
# |    value_loss           | 17.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 811          |
# |    ep_rew_mean          | -28.2        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 90           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0005156828 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.66        |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 5.72         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 1.22e-05     |
# |    std                  | 26           |
# |    value_loss           | 22.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 819           |
# |    ep_rew_mean          | -30           |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 91            |
# |    time_elapsed         | 365           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00022691244 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -4.69         |
# |    explained_variance   | 0.843         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 18.6          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | 0.000488      |
# |    std                  | 26.4          |
# |    value_loss           | 38.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 818          |
# |    ep_rew_mean          | -30          |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 92           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0009424166 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.7         |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 15.2         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | 0.000294     |
# |    std                  | 27           |
# |    value_loss           | 29.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 818         |
# |    ep_rew_mean          | -29         |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 93          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.002992453 |
# |    clip_fraction        | 0.000244    |
# |    clip_range           | 0.8         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.102      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.000923   |
# |    std                  | 28.3        |
# |    value_loss           | 20.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 819          |
# |    ep_rew_mean          | -28.2        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 94           |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0010589875 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.77        |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 11.7         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 29.1         |
# |    value_loss           | 27.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 816           |
# |    ep_rew_mean          | -28           |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 95            |
# |    time_elapsed         | 382           |
# |    total_timesteps      | 194560        |
# | train/                  |               |
# |    approx_kl            | 0.00081315613 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.8           |
# |    entropy_loss         | -4.8          |
# |    explained_variance   | 0.875         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 10.7          |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -0.000385     |
# |    std                  | 30            |
# |    value_loss           | 31.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 816          |
# |    ep_rew_mean          | -28          |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 96           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0015091363 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.83        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 11           |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 30.8         |
# |    value_loss           | 44.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 820          |
# |    ep_rew_mean          | -28.4        |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 97           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0010757816 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.86        |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 8.16         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.000152     |
# |    std                  | 31.7         |
# |    value_loss           | 37.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 819          |
# |    ep_rew_mean          | -27.4        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 98           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0055725044 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.8          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 4.18         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -9.49e-06    |
# |    std                  | 34           |
# |    value_loss           | 9.44         |
# ------------------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.

# %%
from stable_baselines3 import PPO
import torch

# Custom actor (pi) and value function (vf) networks
# of two layers of size 64 each with ReLU activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
policy_kwargs = dict(
    net_arch=dict(pi=[64, 64], vf=[64, 64]), activation_fn=torch.nn.ReLU
)

ent_coef = 0.8
learning_rate = 0.0002  # Experiment with different values
clip_range = 2  # Experiment with different values
# Create the agent
model = PPO("MlpPolicy", "MountainCarContinuous-v0", policy_kwargs=policy_kwargs, verbose=1, ent_coef=ent_coef, learning_rate=learning_rate, clip_range=clip_range)

# Retrieve the environment
env = model.get_env()

# Train the agent
model.learn(total_timesteps=200000)
# Out:
# Using cuda device
# Creating environment from the given name 'MountainCarContinuous-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -52.7    |
# | time/              |          |
# |    fps             | 838      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -53.7        |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0047132466 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.00356      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.18        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.00896      |
# |    std                  | 1.08         |
# |    value_loss           | 0.222        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -54.9       |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003518131 |
# |    clip_fraction        | 0           |
# |    clip_range           | 2           |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -0.033      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.23       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00758     |
# |    std                  | 1.16        |
# |    value_loss           | 0.0568      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -55.7        |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0040003713 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | -0.00855     |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.3         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 0.00675      |
# |    std                  | 1.23         |
# |    value_loss           | 0.0393       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -56.7       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 5           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004115405 |
# |    clip_fraction        | 0           |
# |    clip_range           | 2           |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.00991     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.32       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00773     |
# |    std                  | 1.31        |
# |    value_loss           | 0.0295      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -58.1      |
# | time/                   |            |
# |    fps                  | 537        |
# |    iterations           | 6          |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00352874 |
# |    clip_fraction        | 0          |
# |    clip_range           | 2          |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | 0.0331     |
# |    learning_rate        | 0.0002     |
# |    loss                 | -1.37      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.00759    |
# |    std                  | 1.4        |
# |    value_loss           | 0.028      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -59.1        |
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 7            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0031377873 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.0233       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.41        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 0.00855      |
# |    std                  | 1.49         |
# |    value_loss           | 0.0258       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | -54          |
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 8            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0036316141 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | -0.0268      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.48        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.00703      |
# |    std                  | 1.58         |
# |    value_loss           | 0.0241       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | -55.4        |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 9            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0005619747 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.00294      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.41         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000114    |
# |    std                  | 1.62         |
# |    value_loss           | 43.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | -57          |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 10           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0052231587 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.083       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.55        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.00629      |
# |    std                  | 1.74         |
# |    value_loss           | 0.019        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | -58.4        |
# | time/                   |              |
# |    fps                  | 525          |
# |    iterations           | 11           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0064615975 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | -0.124       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.66        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00375      |
# |    std                  | 1.87         |
# |    value_loss           | 0.0219       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | -59.7        |
# | time/                   |              |
# |    fps                  | 519          |
# |    iterations           | 12           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0041536335 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.00987      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.68        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00501      |
# |    std                  | 2            |
# |    value_loss           | 0.0237       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 998          |
# |    ep_rew_mean          | -60.8        |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 13           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0052371407 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | -0.255       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.74        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.0023       |
# |    std                  | 2.14         |
# |    value_loss           | 0.029        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 998          |
# |    ep_rew_mean          | -61.9        |
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 14           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0038412116 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.79        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.0036       |
# |    std                  | 2.28         |
# |    value_loss           | 0.0226       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 998        |
# |    ep_rew_mean          | -63        |
# | time/                   |            |
# |    fps                  | 518        |
# |    iterations           | 15         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00363489 |
# |    clip_fraction        | 0          |
# |    clip_range           | 2          |
# |    entropy_loss         | -2.28      |
# |    explained_variance   | 0.542      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -1.83      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.00418    |
# |    std                  | 2.43       |
# |    value_loss           | 0.0236     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 998         |
# |    ep_rew_mean          | -64         |
# | time/                   |             |
# |    fps                  | 519         |
# |    iterations           | 16          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004541711 |
# |    clip_fraction        | 0           |
# |    clip_range           | 2           |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | -0.453      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.89       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00393     |
# |    std                  | 2.59        |
# |    value_loss           | 0.0175      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 998          |
# |    ep_rew_mean          | -65          |
# | time/                   |              |
# |    fps                  | 520          |
# |    iterations           | 17           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0047702286 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.0321       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.94        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00438      |
# |    std                  | 2.77         |
# |    value_loss           | 0.0109       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 998         |
# |    ep_rew_mean          | -65.9       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 18          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004010633 |
# |    clip_fraction        | 0           |
# |    clip_range           | 2           |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | -0.0381     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.96       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00422     |
# |    std                  | 2.95        |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 993          |
# |    ep_rew_mean          | -64.2        |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 19           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0036984892 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | -0.336       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.04        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.00343      |
# |    std                  | 3.14         |
# |    value_loss           | 0.0118       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 993           |
# |    ep_rew_mean          | -65.2         |
# | time/                   |               |
# |    fps                  | 517           |
# |    iterations           | 20            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00034273698 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -2.57         |
# |    explained_variance   | 0.00607       |
# |    learning_rate        | 0.0002        |
# |    loss                 | -0.263        |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.000174      |
# |    std                  | 3.2           |
# |    value_loss           | 45.3          |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 994        |
# |    ep_rew_mean          | -66.1      |
# | time/                   |            |
# |    fps                  | 514        |
# |    iterations           | 21         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01061605 |
# |    clip_fraction        | 0          |
# |    clip_range           | 2          |
# |    entropy_loss         | -2.61      |
# |    explained_variance   | -0.341     |
# |    learning_rate        | 0.0002     |
# |    loss                 | -2.11      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0014    |
# |    std                  | 3.41       |
# |    value_loss           | 0.111      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 994         |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 22          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011760844 |
# |    clip_fraction        | 0           |
# |    clip_range           | 2           |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | -0.87       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.17       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00193     |
# |    std                  | 3.67        |
# |    value_loss           | 0.0173      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 992          |
# |    ep_rew_mean          | -65.5        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 23           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0063268146 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | -0.491       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.00418      |
# |    std                  | 3.92         |
# |    value_loss           | 0.0176       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 992           |
# |    ep_rew_mean          | -66.4         |
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 24            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00026507163 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 0.0553        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 28.3          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -5.65e-05     |
# |    std                  | 3.98          |
# |    value_loss           | 44.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 25          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.047733523 |
# |    clip_fraction        | 0.00103     |
# |    clip_range           | 2           |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -0.571      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.22       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00664    |
# |    std                  | 4.26        |
# |    value_loss           | 0.0901      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 971           |
# |    ep_rew_mean          | -61           |
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 26            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00023989921 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0.0778        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 64.6          |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -4.97e-05     |
# |    std                  | 4.3           |
# |    value_loss           | 123           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 966          |
# |    ep_rew_mean          | -60.1        |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 27           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0081119705 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | -0.331       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.98        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000298    |
# |    std                  | 4.5          |
# |    value_loss           | 0.927        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -59.1        |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 28           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0048465203 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 7.55         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 4.56         |
# |    value_loss           | 41.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 957          |
# |    ep_rew_mean          | -58.4        |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 29           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0011136234 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.299        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 12           |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000795    |
# |    std                  | 4.63         |
# |    value_loss           | 36.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 958          |
# |    ep_rew_mean          | -59.4        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 30           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0028526685 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 1.68         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000811    |
# |    std                  | 4.7          |
# |    value_loss           | 33.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | -60.4       |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 31          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.025000602 |
# |    clip_fraction        | 9.77e-05    |
# |    clip_range           | 2           |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.0406      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.26       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00201    |
# |    std                  | 4.95        |
# |    value_loss           | 1.11        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 961          |
# |    ep_rew_mean          | -61.4        |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 32           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0139663415 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 2            |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | -0.868       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -2.45        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.00189      |
# |    std                  | 5.45         |
# |    value_loss           | 0.11         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | -60.6      |
# | time/                   |            |
# |    fps                  | 510        |
# |    iterations           | 33         |
# |    time_elapsed         | 132        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.06417859 |
# |    clip_fraction        | 0.00117    |
# |    clip_range           | 2          |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | -0.804     |
# |    learning_rate        | 0.0002     |
# |    loss                 | -2.59      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00393   |
# |    std                  | 5.91       |
# |    value_loss           | 0.145      |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | -60.2         |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 34            |
# |    time_elapsed         | 136           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00077945576 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.27          |
# |    learning_rate        | 0.0002        |
# |    loss                 | 43.7          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000375     |
# |    std                  | 6.01          |
# |    value_loss           | 34.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 961          |
# |    ep_rew_mean          | -61.1        |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 35           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0003096246 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 71.9         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -4.35e-05    |
# |    std                  | 6.09         |
# |    value_loss           | 34.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 959         |
# |    ep_rew_mean          | -60.5       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 36          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.046988636 |
# |    clip_fraction        | 0.00122     |
# |    clip_range           | 2           |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | -0.368      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.51       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00434    |
# |    std                  | 6.52        |
# |    value_loss           | 0.426       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 951           |
# |    ep_rew_mean          | -58.5         |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 37            |
# |    time_elapsed         | 148           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00016382054 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -3.3          |
# |    explained_variance   | 0.397         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 50.5          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | 0.000149      |
# |    std                  | 6.61          |
# |    value_loss           | 35.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 950           |
# |    ep_rew_mean          | -57.9         |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 38            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00012516076 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -3.31         |
# |    explained_variance   | 0.48          |
# |    learning_rate        | 0.0002        |
# |    loss                 | 39.5          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 7.44e-05      |
# |    std                  | 6.67          |
# |    value_loss           | 56            |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 950        |
# |    ep_rew_mean          | -58        |
# | time/                   |            |
# |    fps                  | 509        |
# |    iterations           | 39         |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01337444 |
# |    clip_fraction        | 0          |
# |    clip_range           | 2          |
# |    entropy_loss         | -3.32      |
# |    explained_variance   | 0.738      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 1.05       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00364   |
# |    std                  | 6.78       |
# |    value_loss           | 17.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 941          |
# |    ep_rew_mean          | -56          |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 40           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0017712587 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 6.46         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000209    |
# |    std                  | 6.86         |
# |    value_loss           | 31.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 941           |
# |    ep_rew_mean          | -55.7         |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 41            |
# |    time_elapsed         | 164           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 8.6463086e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -3.35         |
# |    explained_variance   | 0.657         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 7.08          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 0.000216      |
# |    std                  | 6.92          |
# |    value_loss           | 47.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 942          |
# |    ep_rew_mean          | -55.5        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 42           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0013218747 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -3.36        |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.874        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000316    |
# |    std                  | 7.05         |
# |    value_loss           | 15.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 937           |
# |    ep_rew_mean          | -54.7         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 43            |
# |    time_elapsed         | 173           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00034600135 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -3.38         |
# |    explained_variance   | 0.707         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 39.4          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 0.000128      |
# |    std                  | 7.18          |
# |    value_loss           | 22.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 939         |
# |    ep_rew_mean          | -56.1       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 44          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003176705 |
# |    clip_fraction        | 0           |
# |    clip_range           | 2           |
# |    entropy_loss         | -3.4        |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.79       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000492   |
# |    std                  | 7.38        |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 940         |
# |    ep_rew_mean          | -56.9       |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 45          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.026774354 |
# |    clip_fraction        | 0.00132     |
# |    clip_range           | 2           |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | -1.23       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.76       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0039      |
# |    std                  | 8.39        |
# |    value_loss           | 0.249       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 928           |
# |    ep_rew_mean          | -54.9         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 46            |
# |    time_elapsed         | 185           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00033012652 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -3.55         |
# |    explained_variance   | -0.128        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.769         |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 1.23e-05      |
# |    std                  | 8.53          |
# |    value_loss           | 13.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | -54.6        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 47           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0005532571 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -3.57        |
# |    explained_variance   | 0.671        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 26.3         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000139    |
# |    std                  | 8.6          |
# |    value_loss           | 50.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | -55.4        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 48           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0012845914 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -3.58        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 14.5         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 8.73         |
# |    value_loss           | 27.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 926         |
# |    ep_rew_mean          | -56.2       |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 49          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.021396501 |
# |    clip_fraction        | 0.000537    |
# |    clip_range           | 2           |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | -1.18       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -2.93       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -6.53e-06   |
# |    std                  | 9.72        |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 912         |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 50          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.019081488 |
# |    clip_fraction        | 0.000244    |
# |    clip_range           | 2           |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | -0.723      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -3          |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00313    |
# |    std                  | 10.8        |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 912           |
# |    ep_rew_mean          | -54           |
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 51            |
# |    time_elapsed         | 204           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00020994764 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -3.8          |
# |    explained_variance   | 0.665         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 18            |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000579     |
# |    std                  | 10.8          |
# |    value_loss           | 57.9          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 913         |
# |    ep_rew_mean          | -55.6       |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 52          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# ...
# |    fps                  | 509           |
# |    iterations           | 82            |
# |    time_elapsed         | 329           |
# |    total_timesteps      | 167936        |
# | train/                  |               |
# |    approx_kl            | 0.00017826603 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -4.85         |
# |    explained_variance   | 0.814         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 4.12          |
# |    n_updates            | 810           |
# |    policy_gradient_loss | -0.000172     |
# |    std                  | 31.2          |
# |    value_loss           | 17            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 828           |
# |    ep_rew_mean          | -41.8         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 83            |
# |    time_elapsed         | 334           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 2.0116975e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -4.86         |
# |    explained_variance   | 0.745         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 51.4          |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -5.41e-05     |
# |    std                  | 31.3          |
# |    value_loss           | 94.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 834           |
# |    ep_rew_mean          | -43.4         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 84            |
# |    time_elapsed         | 338           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 5.3032883e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -4.87         |
# |    explained_variance   | 0.724         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 6.65          |
# |    n_updates            | 830           |
# |    policy_gradient_loss | 0.000102      |
# |    std                  | 31.5          |
# |    value_loss           | 26.4          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 831         |
# |    ep_rew_mean          | -42.1       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 85          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.021369036 |
# |    clip_fraction        | 0           |
# |    clip_range           | 2           |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | -1.03       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -3.64       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 33.3        |
# |    value_loss           | 1.81        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 834          |
# |    ep_rew_mean          | -42.4        |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 86           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0001229977 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -1.28        |
# |    n_updates            | 850          |
# |    policy_gradient_loss | 6.06e-05     |
# |    std                  | 33.7         |
# |    value_loss           | 24.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 837           |
# |    ep_rew_mean          | -42.7         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 87            |
# |    time_elapsed         | 350           |
# |    total_timesteps      | 178176        |
# | train/                  |               |
# |    approx_kl            | 0.00010803074 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -4.94         |
# |    explained_variance   | 0.695         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 8.4           |
# |    n_updates            | 860           |
# |    policy_gradient_loss | 0.000194      |
# |    std                  | 34            |
# |    value_loss           | 30.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 832           |
# |    ep_rew_mean          | -42.3         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 88            |
# |    time_elapsed         | 354           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 0.00026102594 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -4.95         |
# |    explained_variance   | 0.845         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 1.88          |
# |    n_updates            | 870           |
# |    policy_gradient_loss | 0.000191      |
# |    std                  | 34.6          |
# |    value_loss           | 10.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 832           |
# |    ep_rew_mean          | -42.3         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 89            |
# |    time_elapsed         | 358           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00045369254 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -4.97         |
# |    explained_variance   | 0.796         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.86          |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.00012      |
# |    std                  | 35.1          |
# |    value_loss           | 22.4          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 830         |
# |    ep_rew_mean          | -40.1       |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 90          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.011549422 |
# |    clip_fraction        | 0.000146    |
# |    clip_range           | 2           |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.0514      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -3.76       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00297    |
# |    std                  | 39.5        |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 831           |
# |    ep_rew_mean          | -41.3         |
# | time/                   |               |
# |    fps                  | 508           |
# |    iterations           | 91            |
# |    time_elapsed         | 366           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 3.8591563e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -5.1          |
# |    explained_variance   | 0.802         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 27.5          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -2.2e-05      |
# |    std                  | 39.8          |
# |    value_loss           | 63.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 823          |
# |    ep_rew_mean          | -38.5        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 92           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0036382154 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -5.12        |
# |    explained_variance   | -0.712       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -3.87        |
# |    n_updates            | 910          |
# |    policy_gradient_loss | 0.000435     |
# |    std                  | 41.8         |
# |    value_loss           | 1.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 826          |
# |    ep_rew_mean          | -39.8        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 93           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0002962323 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -5.16        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 18.6         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.000491    |
# |    std                  | 42.1         |
# |    value_loss           | 41.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 826          |
# |    ep_rew_mean          | -39.8        |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 94           |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0004097874 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -5.17        |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.884       |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -5.57e-05    |
# |    std                  | 42.7         |
# |    value_loss           | 11.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 826          |
# |    ep_rew_mean          | -39.9        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 95           |
# |    time_elapsed         | 383          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0031013242 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -5.2         |
# |    explained_variance   | 0.0765       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -3.53        |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.000826     |
# |    std                  | 45.3         |
# |    value_loss           | 1.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 823          |
# |    ep_rew_mean          | -38.7        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 96           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0010975469 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -5.24        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.812       |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.000576    |
# |    std                  | 46.2         |
# |    value_loss           | 7.5          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 817           |
# |    ep_rew_mean          | -38.1         |
# | time/                   |               |
# |    fps                  | 507           |
# |    iterations           | 97            |
# |    time_elapsed         | 391           |
# |    total_timesteps      | 198656        |
# | train/                  |               |
# |    approx_kl            | 0.00011526098 |
# |    clip_fraction        | 0             |
# |    clip_range           | 2             |
# |    entropy_loss         | -5.25         |
# |    explained_variance   | 0.815         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 29.4          |
# |    n_updates            | 960           |
# |    policy_gradient_loss | -5.51e-05     |
# |    std                  | 46.4          |
# |    value_loss           | 67            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 811          |
# |    ep_rew_mean          | -35.5        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 98           |
# |    time_elapsed         | 395          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0004156291 |
# |    clip_fraction        | 0            |
# |    clip_range           | 2            |
# |    entropy_loss         | -5.26        |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.29         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.000546    |
# |    std                  | 47           |
# |    value_loss           | 25.2         |
# ------------------------------------------

# %%
vec_env = model.get_env()
obs = vec_env.reset()
imgs = []
done = False
while not done:
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action) # Notice the difference between
    img = vec_env.render("rgb_array")
    imgs.append(img)

env.close()

save_video(imgs, path='')
# Out:
# Video saved.
